# %%
print("This week 3 assignment-Segmenting and Clustering Neighborhoods in Toronto")
# Out:
# This week 3 assignment-Segmenting and Clustering Neighborhoods in Toronto

# %%
import pandas as pd
import numpy as np

# %%
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"

# %%
from lxml import *

# %%
data= pd.read_html(url)

# %%
data
# Out:
# [    Postcode           Borough          Neighbourhood
#  0        M1A      Not assigned           Not assigned
#  1        M2A      Not assigned           Not assigned
#  2        M3A        North York              Parkwoods
#  3        M4A        North York       Victoria Village
#  4        M5A  Downtown Toronto           Harbourfront
#  ..       ...               ...                    ...
#  283      M8Z         Etobicoke              Mimico NW
#  284      M8Z         Etobicoke     The Queensway West
#  285      M8Z         Etobicoke  Royal York South West
#  286      M8Z         Etobicoke         South of Bloor
#  287      M9Z      Not assigned           Not assigned
#
#  [288 rows x 3 columns],
#                                                    0   \
#  0                                                NaN
#  1  NL NS PE NB QC ON MB SK AB BC NU/NT YT A B C E...
#  2                                                 NL
#  3                                                  A
#
# ...

# %%
# Out:
#     Postcode           Borough          Neighbourhood
# 0        M1A      Not assigned           Not assigned
# 1        M2A      Not assigned           Not assigned
# 2        M3A        North York              Parkwoods
# 3        M4A        North York       Victoria Village
# 4        M5A  Downtown Toronto           Harbourfront
# ..       ...               ...                    ...
# 283      M8Z         Etobicoke              Mimico NW
# 284      M8Z         Etobicoke     The Queensway West
# 285      M8Z         Etobicoke  Royal York South West
# 286      M8Z         Etobicoke         South of Bloor
# 287      M9Z      Not assigned           Not assigned
#
# [288 rows x 3 columns]

# %%
data1=pd.DataFrame(data[0])

# %%
data1.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M1A      Not assigned      Not assigned
# 1      M2A      Not assigned      Not assigned
# 2      M3A        North York         Parkwoods
# 3      M4A        North York  Victoria Village
# 4      M5A  Downtown Toronto      Harbourfront

# %%
data1["Postcode"]
# Out:
# 0      M1A
# 1      M2A
# 2      M3A
# 3      M4A
# 4      M5A
#       ...
# 283    M8Z
# 284    M8Z
# 285    M8Z
# 286    M8Z
# 287    M9Z
# Name: Postcode, Length: 288, dtype: object

# %%
data1.dropna(subset=["Borough"],axis=0, inplace=True)

# %%
data2=data1.drop([0],axis=0)

# %%
data2
# Out:
#     Postcode           Borough          Neighbourhood
# 1        M2A      Not assigned           Not assigned
# 2        M3A        North York              Parkwoods
# 3        M4A        North York       Victoria Village
# 4        M5A  Downtown Toronto           Harbourfront
# 5        M5A  Downtown Toronto            Regent Park
# ..       ...               ...                    ...
# 283      M8Z         Etobicoke              Mimico NW
# 284      M8Z         Etobicoke     The Queensway West
# 285      M8Z         Etobicoke  Royal York South West
# 286      M8Z         Etobicoke         South of Bloor
# 287      M9Z      Not assigned           Not assigned
#
# [287 rows x 3 columns]

# %%
j=0
a=[]
for  i in data1["Borough"]:
    if("Not assigned" == i):
        a.append(j)
    j=j+1

# %%
data2=data1.drop(a,axis=0)

# %%
data2
# Out:
#     Postcode           Borough             Neighbourhood
# 2        M3A        North York                 Parkwoods
# 3        M4A        North York          Victoria Village
# 4        M5A  Downtown Toronto              Harbourfront
# 5        M5A  Downtown Toronto               Regent Park
# 6        M6A        North York          Lawrence Heights
# ..       ...               ...                       ...
# 282      M8Z         Etobicoke  Kingsway Park South West
# 283      M8Z         Etobicoke                 Mimico NW
# 284      M8Z         Etobicoke        The Queensway West
# 285      M8Z         Etobicoke     Royal York South West
# 286      M8Z         Etobicoke            South of Bloor
#
# [211 rows x 3 columns]

# %%
data2.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Not assigned
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %%
data2.describe()
# Out:
#        Postcode    Borough Neighbourhood
# count       211        211           211
# unique      103         11           209
# top         M9V  Etobicoke     Runnymede
# freq          8         45             2

# %%
data2.head(10)
# Out:
#    Postcode           Borough     Neighbourhood
# 2       M3A        North York         Parkwoods
# 3       M4A        North York  Victoria Village
# 4       M5A  Downtown Toronto      Harbourfront
# 5       M5A  Downtown Toronto       Regent Park
# 6       M6A        North York  Lawrence Heights
# 7       M6A        North York    Lawrence Manor
# 8       M7A      Queen's Park      Not assigned
# 10      M9A         Etobicoke  Islington Avenue
# 11      M1B       Scarborough             Rouge
# 12      M1B       Scarborough           Malvern

# %%
df3=data2
df3
# Out:
#     Postcode           Borough             Neighbourhood
# 2        M3A        North York                 Parkwoods
# 3        M4A        North York          Victoria Village
# 4        M5A  Downtown Toronto              Harbourfront
# 5        M5A  Downtown Toronto               Regent Park
# 6        M6A        North York          Lawrence Heights
# ..       ...               ...                       ...
# 282      M8Z         Etobicoke  Kingsway Park South West
# 283      M8Z         Etobicoke                 Mimico NW
# 284      M8Z         Etobicoke        The Queensway West
# 285      M8Z         Etobicoke     Royal York South West
# 286      M8Z         Etobicoke            South of Bloor
#
# [211 rows x 3 columns]

# %%
df3.insert(loc=0,column="", value=np.arange(len(df3)))
df3
# Out:
#          Postcode           Borough             Neighbourhood
# 2      0      M3A        North York                 Parkwoods
# 3      1      M4A        North York          Victoria Village
# 4      2      M5A  Downtown Toronto              Harbourfront
# 5      3      M5A  Downtown Toronto               Regent Park
# 6      4      M6A        North York          Lawrence Heights
# ..   ...      ...               ...                       ...
# 282  206      M8Z         Etobicoke  Kingsway Park South West
# 283  207      M8Z         Etobicoke                 Mimico NW
# 284  208      M8Z         Etobicoke        The Queensway West
# 285  209      M8Z         Etobicoke     Royal York South West
# 286  210      M8Z         Etobicoke            South of Bloor
#
# [211 rows x 4 columns]

# %%
df3.set_index("",inplace=True)

# %%
df3.head(60)
# Out:
#    Postcode           Borough        Neighbourhood
#
# 0       M3A        North York            Parkwoods
# 1       M4A        North York     Victoria Village
# 2       M5A  Downtown Toronto         Harbourfront
# 3       M5A  Downtown Toronto          Regent Park
# 4       M6A        North York     Lawrence Heights
# 5       M6A        North York       Lawrence Manor
# 6       M7A      Queen's Park         Not assigned
# 7       M9A         Etobicoke     Islington Avenue
# 8       M1B       Scarborough                Rouge
# 9       M1B       Scarborough              Malvern
# 10      M3B        North York      Don Mills North
# 11      M4B         East York     Woodbine Gardens
# 12      M4B         East York        Parkview Hill
# 13      M5B  Downtown Toronto              Ryerson
# 14      M5B  Downtown Toronto      Garden District
# 15      M6B        North York            Glencairn
# 16      M9B         Etobicoke           Cloverdale
# ...

# %%
a=[]
j=0
for i in df3["Neighbourhood"]:
    if("Not assigned" == i):
        df3["Neighbourhood"][j]=df3["Borough"][j]
    j=j+1
df3.head(20)
# Out:
#    Postcode           Borough     Neighbourhood
#
# 0       M3A        North York         Parkwoods
# 1       M4A        North York  Victoria Village
# 2       M5A  Downtown Toronto      Harbourfront
# 3       M5A  Downtown Toronto       Regent Park
# 4       M6A        North York  Lawrence Heights
# 5       M6A        North York    Lawrence Manor
# 6       M7A      Queen's Park      Queen's Park
# 7       M9A         Etobicoke  Islington Avenue
# 8       M1B       Scarborough             Rouge
# 9       M1B       Scarborough           Malvern
# 10      M3B        North York   Don Mills North
# 11      M4B         East York  Woodbine Gardens
# 12      M4B         East York     Parkview Hill
# 13      M5B  Downtown Toronto           Ryerson
# 14      M5B  Downtown Toronto   Garden District
# 15      M6B        North York         Glencairn
# 16      M9B         Etobicoke        Cloverdale
# 17      M9B         Etobicoke         Islington
# ...

# %%
postuni=df3["Postcode"].unique()
postuni
# Out:
# array(['M3A', 'M4A', 'M5A', 'M6A', 'M7A', 'M9A', 'M1B', 'M3B', 'M4B',
#        'M5B', 'M6B', 'M9B', 'M1C', 'M3C', 'M4C', 'M5C', 'M6C', 'M9C',
#        'M1E', 'M4E', 'M5E', 'M6E', 'M1G', 'M4G', 'M5G', 'M6G', 'M1H',
#        'M2H', 'M3H', 'M4H', 'M5H', 'M6H', 'M1J', 'M2J', 'M3J', 'M4J',
#        'M5J', 'M6J', 'M1K', 'M2K', 'M3K', 'M4K', 'M5K', 'M6K', 'M1L',
#        'M2L', 'M3L', 'M4L', 'M5L', 'M6L', 'M9L', 'M1M', 'M2M', 'M3M',
#        'M4M', 'M5M', 'M6M', 'M9M', 'M1N', 'M2N', 'M3N', 'M4N', 'M5N',
#        'M6N', 'M9N', 'M1P', 'M2P', 'M4P', 'M5P', 'M6P', 'M9P', 'M1R',
#        'M2R', 'M4R', 'M5R', 'M6R', 'M7R', 'M9R', 'M1S', 'M4S', 'M5S',
#        'M6S', 'M1T', 'M4T', 'M5T', 'M1V', 'M4V', 'M5V', 'M8V', 'M9V',
#        'M1W', 'M4W', 'M5W', 'M8W', 'M9W', 'M1X', 'M4X', 'M5X', 'M8X',
#        'M4Y', 'M7Y', 'M8Y', 'M8Z'], dtype=object)

# %%
df4=df3
df4
# Out:
#     Postcode           Borough             Neighbourhood
# 0        M3A        North York                 Parkwoods
# 1        M4A        North York          Victoria Village
# 2        M5A  Downtown Toronto              Harbourfront
# 3        M5A  Downtown Toronto               Regent Park
# 4        M6A        North York          Lawrence Heights
# ..       ...               ...                       ...
# 206      M8Z         Etobicoke  Kingsway Park South West
# 207      M8Z         Etobicoke                 Mimico NW
# 208      M8Z         Etobicoke        The Queensway West
# 209      M8Z         Etobicoke     Royal York South West
# 210      M8Z         Etobicoke            South of Bloor
#
# [211 rows x 3 columns]

# %%
df4
# Out:
#     Postcode           Borough             Neighbourhood
# 0        M3A        North York                 Parkwoods
# 1        M4A        North York          Victoria Village
# 2        M5A  Downtown Toronto              Harbourfront
# 3        M5A  Downtown Toronto               Regent Park
# 4        M6A        North York          Lawrence Heights
# ..       ...               ...                       ...
# 206      M8Z         Etobicoke  Kingsway Park South West
# 207      M8Z         Etobicoke                 Mimico NW
# 208      M8Z         Etobicoke        The Queensway West
# 209      M8Z         Etobicoke     Royal York South West
# 210      M8Z         Etobicoke            South of Bloor
#
# [211 rows x 3 columns]

# %%
df4.groupby(["Postcode","Borough"])
df4
# Out:
#     Postcode           Borough             Neighbourhood
# 0        M3A        North York                 Parkwoods
# 1        M4A        North York          Victoria Village
# 2        M5A  Downtown Toronto              Harbourfront
# 3        M5A  Downtown Toronto               Regent Park
# 4        M6A        North York          Lawrence Heights
# ..       ...               ...                       ...
# 206      M8Z         Etobicoke  Kingsway Park South West
# 207      M8Z         Etobicoke                 Mimico NW
# 208      M8Z         Etobicoke        The Queensway West
# 209      M8Z         Etobicoke     Royal York South West
# 210      M8Z         Etobicoke            South of Bloor
#
# [211 rows x 3 columns]

# %%
df5=pd.DataFrame(df4.groupby(["Postcode","Borough"])["Neighbourhood"].apply(",".join))
df5
# Out:
#                                                           Neighbourhood
# Postcode Borough
# M1B      Scarborough                                      Rouge,Malvern
# M1C      Scarborough               Highland Creek,Rouge Hill,Port Union
# M1E      Scarborough                    Guildwood,Morningside,West Hill
# M1G      Scarborough                                             Woburn
# M1H      Scarborough                                          Cedarbrae
# ...                                                                 ...
# M9N      York                                                    Weston
# M9P      Etobicoke                                            Westmount
# M9R      Etobicoke    Kingsview Village,Martin Grove Gardens,Richvie...
# M9V      Etobicoke    Albion Gardens,Beaumond Heights,Humbergate,Jam...
# M9W      Etobicoke                                            Northwest
#
# [103 rows x 1 columns]

# %%
df5
# Out:
#                                                           Neighbourhood
# Postcode Borough
# M1B      Scarborough                                      Rouge,Malvern
# M1C      Scarborough               Highland Creek,Rouge Hill,Port Union
# M1E      Scarborough                    Guildwood,Morningside,West Hill
# M1G      Scarborough                                             Woburn
# M1H      Scarborough                                          Cedarbrae
# ...                                                                 ...
# M9N      York                                                    Weston
# M9P      Etobicoke                                            Westmount
# M9R      Etobicoke    Kingsview Village,Martin Grove Gardens,Richvie...
# M9V      Etobicoke    Albion Gardens,Beaumond Heights,Humbergate,Jam...
# M9W      Etobicoke                                            Northwest
#
# [103 rows x 1 columns]

# %%
df5.reset_index(level=['Postcode','Borough'],inplace=True)
df5
# Out:
#     Postcode      Borough                                      Neighbourhood
# 0        M1B  Scarborough                                      Rouge,Malvern
# 1        M1C  Scarborough               Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough                    Guildwood,Morningside,West Hill
# 3        M1G  Scarborough                                             Woburn
# 4        M1H  Scarborough                                          Cedarbrae
# ..       ...          ...                                                ...
# 98       M9N         York                                             Weston
# 99       M9P    Etobicoke                                          Westmount
# 100      M9R    Etobicoke  Kingsview Village,Martin Grove Gardens,Richvie...
# 101      M9V    Etobicoke  Albion Gardens,Beaumond Heights,Humbergate,Jam...
# 102      M9W    Etobicoke                                          Northwest
#
# [103 rows x 3 columns]

# %%
df5.head(50)
# Out:
#    Postcode          Borough  \
# 0       M1B      Scarborough
# 1       M1C      Scarborough
# 2       M1E      Scarborough
# 3       M1G      Scarborough
# 4       M1H      Scarborough
# 5       M1J      Scarborough
# 6       M1K      Scarborough
# 7       M1L      Scarborough
# 8       M1M      Scarborough
# 9       M1N      Scarborough
# 10      M1P      Scarborough
# 11      M1R      Scarborough
# 12      M1S      Scarborough
# 13      M1T      Scarborough
# 14      M1V      Scarborough
# 15      M1W      Scarborough
# 16      M1X      Scarborough
# 17      M2H       North York
# 18      M2J       North York
# 19      M2K       North York
# 20      M2L       North York
# 21      M2M       North York
# 22      M2N       North York
# 23      M2P       North York
# 24      M2R       North York
# 25      M3A       North York
# 26      M3B       North York
# 27      M3C       North York
# 28      M3H       North York
# 29      M3J       North York
# 30      M3K       North York
# ...
